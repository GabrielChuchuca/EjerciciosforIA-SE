# %% [markdown]
# # INSTALAR NEOJ4 COMMUNITY SERVER y averiguar las diferencias que hay entre la enterprise y community

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
